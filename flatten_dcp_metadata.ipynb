# %%
import pandas as pd
import numpy as np
import os

# %%
from metadata_dict import (hca_keys, dcp_to_tier1_mapping)

# %% [markdown]
# Please specify the `file_name` of the dcp spreadsheet, that exists in the `dcp_path`

# %%
dcp_path = "./dcp_spreadsheets/"
flat_path = "./flat_dcp/"
tier1_path = "./tier1_output/"
file_name = "ImmuneLandscapeccRCC_metadata_30-01-2023.xlsx"

# %%
spreadsheet = pd.read_excel(os.path.join(dcp_path, file_name), sheet_name=None, skiprows= [0,1,2,4])

# %%
# Save all biomaterials and protocols from each tab as join keys

join_keys = {}
join_set = set()
for sheet in spreadsheet:
    join_keys[sheet] = []
    for key in spreadsheet[sheet].keys():
        if (key.endswith("biomaterial_id") or key.endswith("protocol_id")) and (not all(spreadsheet[sheet][key].isna())):
            join_keys[sheet].append(key)
            join_set.add(key)
    if not join_keys[sheet]:
        del join_keys[sheet]

# %%
# Save keys that have double pipe in order to merge metadata together for those keys

keys_with_double_pipe = []
for sheet in join_keys.keys():
    for keys in join_keys[sheet]:
        if any(spreadsheet[sheet][keys].str.contains("\\|\\|")):
            keys_with_double_pipe.append(keys)
keys_with_double_pipe
# Out:
# ['enrichment_protocol.protocol_core.protocol_id',
#  'dissociation_protocol.protocol_core.protocol_id',
#  'cell_suspension.biomaterial_core.biomaterial_id']

# %%
# Manually order the spreadsheet tabs in the `ordered_sheet` list, in order to trace back the experimental design
# Most common experiemntal design is Analysis file -> CS -> Specimen -> Donor

list(join_keys.values())
# default ordering for simple experimental design & protocols
ordered_sheet = ['Analysis file', 'Cell suspension', 'Specimen from organism', 'Donor organism', 
                 'Analysis protocol', 'Sequencing protocol', 'Library preparation protocol', 'Dissociation protocol', 'Enrichment protocol', 'Collection protocol']

# %%
# filter out analysis files that will create duplicates i.e. barcodes and features for same CS and remove analysis_files that did not derive from CS
spreadsheet['Analysis file'] = spreadsheet['Analysis file'][spreadsheet['Analysis file']['analysis_file.file_core.content_description.ontology']\
        .isin(['data:3917', 'data:3112'])]\
    .dropna(subset='cell_suspension.biomaterial_core.biomaterial_id')

# If we have pooled CS for analysis_files, create a new entry for each CS of each file
analysis_pooledCS = spreadsheet['Analysis file']['cell_suspension.biomaterial_core.biomaterial_id'].str.contains("\\|\\|")
if any(analysis_pooledCS):
    print(f"analysis files are pooled")
    spreadsheet['Analysis file']['cell_suspension.biomaterial_core.biomaterial_id'] = \
        spreadsheet['Analysis file']['cell_suspension.biomaterial_core.biomaterial_id']\
            .str.split('\\|\\|')\
            .apply(lambda x: x[0] if len(x) == 1 else x)
    spreadsheet['Analysis file'] = spreadsheet['Analysis file'].explode('cell_suspension.biomaterial_core.biomaterial_id')

# Initiate barcode df with analysis_files and unique cell_suspensions
bc = spreadsheet['Analysis file'][['cell_suspension.biomaterial_core.biomaterial_id','analysis_file.file_core.file_name']]\
    .drop_duplicates('cell_suspension.biomaterial_core.biomaterial_id')
# Out:
# analysis files are pooled

# %%
# edit specific process field names to capture since there are multiple process fields in each sheet

process_fields = {
    'Specimen from organism': {'process.process_core.location': 'sample_collection_site'},
    'Sequence file': {'process.process_core.process_id': 'library_sequencing_run'}
}

for sheet in process_fields:
    if sheet not in spreadsheet:
        continue
    spreadsheet[sheet] = spreadsheet[sheet].rename(columns=process_fields[sheet])

# %%
# If no analysis files available provide flatten metatadata at the sample level based on the CS from the sequence file tab
# create the backbone of the flatten metadata from the sequence file tab, removing all sequence file specific fields and removing duplicate entries 
if 'Analysis file' not in spreadsheet.keys():
    seq_specific_fields = ['sequence_file.file_core.file_name', 'sequence_file.file_core.format', 
                       'sequence_file.insdc_run_accessions', 'sequence_file.file_core.content_description.text', 
                       'sequence_file.file_core.content_description.ontology', 
                       'sequence_file.file_core.content_description.ontology_label', 'sequence_file.read_index',
                       'sequence_file.uuid', 'sequence_file.file_core.file_source', 'sequence_file.read_length', 
                       'process.uuid', 'process.insdc_experiment.insdc_experiment_accession', 'process.process_core.process_id', 
                       'sequencing_protocol.protocol_core.protocol_id', 'sequencing_protocol.uuid', 
                       'library_preparation_protocol.protocol_core.protocol_id', 'library_preparation_protocol.uuid', 
                       'sequence_file.lane_index']
    bc = spreadsheet['Sequence file'].dropna(axis=1, how= "all").drop(columns=seq_specific_fields).drop_duplicates()

# %%
# if we have pooled keys, edit the spreadsheet and add the pooled values as extra rows

def process_pooled_keys(sheet, bc, join_key):
    pooled_keys = [key for key in bc[join_key].dropna().unique().tolist() if "||" in key]
    print("We have pooled join keys", pooled_keys)
    for key in pooled_keys:
        unpooled_bool = sheet[join_key].isin(key.split("||"))
        summary_row = {}
        unique_values = {}
        # df.loc[unpooled_bool] = df.loc[unpooled_bool].astype('string')
        # unique_values = df.loc[unpooled_bool].apply(lambda col: col.unique()).to_dict()
        # unique_values = df.loc[unpooled_bool].apply(lambda col: col.unique()).to_dict('list')
        # unique_values = {col : list(contents.dropna().astype('str').unique()) for col, contents in df.loc[unpooled_bool].items()}
        for col, contents in sheet.loc[unpooled_bool].items():
            unique_values[col] = list(contents.dropna().astype('str').unique())
            if len(unique_values[col]) == 1:
                unique_values[col] = unique_values[col][0]
        for col, values in unique_values.items():
            # if 'nan' in values and len(values) > 1:
            #     unique_values[col] = values[values != 'nan']
            if isinstance(values, list) and len(values) > 1:
                summary_row[col] = '||'.join(values)
            else:
                summary_row[col] = values
        # summary_row = {col: '||'.join(values) if len(values) > 1 else values[0]
        #     for col, values in unique_values.items()}
        id_key = [name for name in summary_row.keys() if name.endswith("_id")]
        if len(id_key) > 1:
            print("Multiple id keys")
        summary_row[id_key[0]] = key
        return pd.concat([sheet, pd.DataFrame([summary_row])], ignore_index=True)

# %%
# in each sheet merge the flat df with the spreadsheet

for sheet in ordered_sheet:
    if sheet not in spreadsheet.keys():
        continue
    keys_in_tab = spreadsheet[sheet].keys()
    join_key = [key for key in keys_in_tab if key in bc.keys() and key in join_set]
    if len(join_key) > 1:
        print("Multiple join keys in " + sheet + ":\n\t" + "\n\t".join(join_key))
        if 'analysis_file.file_core.file_name' in join_key:
            join_key = 'analysis_file.file_core.file_name'
    else:
        join_key = join_key[0]

    keys_in_tab = [key for key in keys_in_tab if key not in bc.keys() or key == join_key]
    if join_key in keys_with_double_pipe and any(bc[join_key].str.contains("\\|\\|")):
        spreadsheet[sheet] = process_pooled_keys(spreadsheet[sheet], bc, join_key)

    print("Merging sheet " + sheet + " on key " + join_key, sep = "\t")
    bc = bc.merge(spreadsheet[sheet][keys_in_tab], on = join_key, how = "left")
    print("Shape is " + str(bc.shape))
bc
# Out:
# Merging sheet Analysis file on key cell_suspension.biomaterial_core.biomaterial_id
# Shape is (29, 19)
# Merging sheet Cell suspension on key cell_suspension.biomaterial_core.biomaterial_id
# Shape is (29, 38)
# Merging sheet Specimen from organism on key specimen_from_organism.biomaterial_core.biomaterial_id
# Shape is (29, 55)
# Merging sheet Donor organism on key donor_organism.biomaterial_core.biomaterial_id
# Shape is (29, 75)
# Merging sheet Analysis protocol on key analysis_protocol.protocol_core.protocol_id
# Shape is (29, 82)
# Merging sheet Sequencing protocol on key sequencing_protocol.protocol_core.protocol_id
# Shape is (29, 93)
# Merging sheet Library preparation protocol on key library_preparation_protocol.protocol_core.protocol_id
# Shape is (29, 114)
# We have pooled join keys ['enzymatic_dissociation||mechanical_dissociation']
# Merging sheet Dissociation protocol on key dissociation_protocol.protocol_core.protocol_id
# Shape is (29, 119)
# We have pooled join keys ['live_cell_selection||size_selection']
# Merging sheet Enrichment protocol on key enrichment_protocol.protocol_core.protocol_id
# Shape is (29, 126)
# Merging sheet Collection protocol on key collection_protocol.protocol_core.protocol_id
# Shape is (29, 131)
#    cell_suspension.biomaterial_core.biomaterial_id  \
# 0                       IpiNivo_Complete_kidney_CS
# 1                         IpiNivo_Complete_PBMC_CS
# 2                        NivoExposed_tumor_Near_CS
# 3                              UT1_tumor_Center_CS
# 4                         NivoExposed_tumor_Far_CS
# 5                                UT2_tumor_Near_CS
# 6                                    UT2_kidney_CS
# 7                          IpiNivo_Mixed_kidney_CS
# 8                            IpiNivo_Mixed_PBMC_CS
# 9                      IpiNivo_Mixed_tumor_Near_CS
# 10                  IpiNivo_Complete_tumor_Near_CS
# 11                IpiNivo_Complete_tumor_Center_CS
# 12                   IpiNivo_Complete_tumor_Far_CS
# 13                               UT1_tumor_Near_CS
# 14                                UT1_tumor_Far_CS
# 15                                   UT1_kidney_CS
# 16                     NivoExposed_tumor_Center_CS
# 17                             UT2_tumor_Center_CS
# 18                           NivoExposed_kidney_CS
# 19                  IpiNivo_Resistant_tumor_Far_CS
# 20                 IpiNivo_Resistant_tumor_Near_CS
# 21                                UT2_tumor_Far_CS
# 22                 IpiNivo_Resistant_lymph_node_CS
# 23                     IpiNivo_Resistant_kidney_CS
# 24                       IpiNivo_Resistant_PBMC_CS
# 25                   IpiNivo_Mixed_tumor_Center_CS
# 26                      IpiNivo_Mixed_tumor_Far_CS
# 27                             NivoExposed_PBMC_CS
# 28               IpiNivo_Resistant_tumor_Center_CS
#
#    analysis_file.file_core.file_name                    analysis_file.uuid  \
# 0              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 1              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 2              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 3              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 4              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 5              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 6              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 7              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 8              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 9              ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 10             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 11             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 12             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 13             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 14             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 15             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 16             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 17             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 18             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 19             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 20             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 21             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 22             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 23             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 24             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 25             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 26             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 27             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
# 28             ccRCC_6pat_Seurat.rds  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f
#
#    analysis_file.file_core.format  \
# 0                             rds
# 1                             rds
# 2                             rds
# 3                             rds
# 4                             rds
# 5                             rds
# 6                             rds
# 7                             rds
# 8                             rds
# 9                             rds
# 10                            rds
# 11                            rds
# 12                            rds
# 13                            rds
# 14                            rds
# 15                            rds
# 16                            rds
# 17                            rds
# 18                            rds
# 19                            rds
# 20                            rds
# 21                            rds
# 22                            rds
# 23                            rds
# 24                            rds
# 25                            rds
# 26                            rds
# 27                            rds
# 28                            rds
#
#    analysis_file.file_core.content_description.text  \
# 0                                      count matrix
# 1                                      count matrix
# 2                                      count matrix
# 3                                      count matrix
# 4                                      count matrix
# 5                                      count matrix
# 6                                      count matrix
# 7                                      count matrix
# 8                                      count matrix
# 9                                      count matrix
# 10                                     count matrix
# 11                                     count matrix
# 12                                     count matrix
# 13                                     count matrix
# 14                                     count matrix
# 15                                     count matrix
# 16                                     count matrix
# 17                                     count matrix
# 18                                     count matrix
# 19                                     count matrix
# 20                                     count matrix
# 21                                     count matrix
# 22                                     count matrix
# 23                                     count matrix
# 24                                     count matrix
# 25                                     count matrix
# 26                                     count matrix
# 27                                     count matrix
# 28                                     count matrix
#
#    analysis_file.file_core.content_description.ontology  \
# 0                                           data:3917
# 1                                           data:3917
# 2                                           data:3917
# 3                                           data:3917
# 4                                           data:3917
# 5                                           data:3917
# 6                                           data:3917
# 7                                           data:3917
# 8                                           data:3917
# 9                                           data:3917
# 10                                          data:3917
# 11                                          data:3917
# 12                                          data:3917
# 13                                          data:3917
# 14                                          data:3917
# 15                                          data:3917
# 16                                          data:3917
# 17                                          data:3917
# 18                                          data:3917
# 19                                          data:3917
# 20                                          data:3917
# 21                                          data:3917
# 22                                          data:3917
# 23                                          data:3917
# 24                                          data:3917
# 25                                          data:3917
# 26                                          data:3917
# 27                                          data:3917
# 28                                          data:3917
#
#    analysis_file.file_core.content_description.ontology_label  \
# 0                                        Count matrix
# 1                                        Count matrix
# 2                                        Count matrix
# 3                                        Count matrix
# 4                                        Count matrix
# 5                                        Count matrix
# 6                                        Count matrix
# 7                                        Count matrix
# 8                                        Count matrix
# 9                                        Count matrix
# 10                                       Count matrix
# 11                                       Count matrix
# 12                                       Count matrix
# 13                                       Count matrix
# 14                                       Count matrix
# 15                                       Count matrix
# 16                                       Count matrix
# 17                                       Count matrix
# 18                                       Count matrix
# 19                                       Count matrix
# 20                                       Count matrix
# 21                                       Count matrix
# 22                                       Count matrix
# 23                                       Count matrix
# 24                                       Count matrix
# 25                                       Count matrix
# 26                                       Count matrix
# 27                                       Count matrix
# 28                                       Count matrix
#
#    analysis_file.file_core.file_source  analysis_file.matrix_cell_count  \
# 0                          Publication                         167283.0
# 1                          Publication                         167283.0
# 2                          Publication                         167283.0
# 3                          Publication                         167283.0
# 4                          Publication                         167283.0
# 5                          Publication                         167283.0
# 6                          Publication                         167283.0
# 7                          Publication                         167283.0
# 8                          Publication                         167283.0
# 9                          Publication                         167283.0
# 10                         Publication                         167283.0
# 11                         Publication                         167283.0
# 12                         Publication                         167283.0
# 13                         Publication                         167283.0
# 14                         Publication                         167283.0
# 15                         Publication                         167283.0
# 16                         Publication                         167283.0
# 17                         Publication                         167283.0
# 18                         Publication                         167283.0
# 19                         Publication                         167283.0
# 20                         Publication                         167283.0
# 21                         Publication                         167283.0
# 22                         Publication                         167283.0
# 23                         Publication                         167283.0
# 24                         Publication                         167283.0
# 25                         Publication                         167283.0
# 26                         Publication                         167283.0
# 27                         Publication                         167283.0
# 28                         Publication                         167283.0
#
#    analysis_file.genome_assembly_version  ...  \
# 0                                 GRCh37  ...
# 1                                 GRCh37  ...
# 2                                 GRCh37  ...
# 3                                 GRCh37  ...
# 4                                 GRCh37  ...
# 5                                 GRCh37  ...
# 6                                 GRCh37  ...
# 7                                 GRCh37  ...
# 8                                 GRCh37  ...
# 9                                 GRCh37  ...
# 10                                GRCh37  ...
# 11                                GRCh37  ...
# 12                                GRCh37  ...
# 13                                GRCh37  ...
# 14                                GRCh37  ...
# 15                                GRCh37  ...
# 16                                GRCh37  ...
# 17                                GRCh37  ...
# 18                                GRCh37  ...
# 19                                GRCh37  ...
# 20                                GRCh37  ...
# 21                                GRCh37  ...
# 22                                GRCh37  ...
# 23                                GRCh37  ...
# 24                                GRCh37  ...
# 25                                GRCh37  ...
# 26                                GRCh37  ...
# 27                                GRCh37  ...
# 28                                GRCh37  ...
#
#     enrichment_protocol.method.text enrichment_protocol.method.ontology  \
# 0         cell size selection||FACS            EFO:0009337||EFO:0009108
# 1   density gradient centrifugation                         EFO:0009112
# 2         cell size selection||FACS            EFO:0009337||EFO:0009108
# 3         cell size selection||FACS            EFO:0009337||EFO:0009108
# 4         cell size selection||FACS            EFO:0009337||EFO:0009108
# 5         cell size selection||FACS            EFO:0009337||EFO:0009108
# 6         cell size selection||FACS            EFO:0009337||EFO:0009108
# 7         cell size selection||FACS            EFO:0009337||EFO:0009108
# 8   density gradient centrifugation                         EFO:0009112
# 9         cell size selection||FACS            EFO:0009337||EFO:0009108
# 10        cell size selection||FACS            EFO:0009337||EFO:0009108
# 11        cell size selection||FACS            EFO:0009337||EFO:0009108
# 12        cell size selection||FACS            EFO:0009337||EFO:0009108
# 13        cell size selection||FACS            EFO:0009337||EFO:0009108
# 14        cell size selection||FACS            EFO:0009337||EFO:0009108
# 15        cell size selection||FACS            EFO:0009337||EFO:0009108
# 16        cell size selection||FACS            EFO:0009337||EFO:0009108
# 17        cell size selection||FACS            EFO:0009337||EFO:0009108
# 18        cell size selection||FACS            EFO:0009337||EFO:0009108
# 19        cell size selection||FACS            EFO:0009337||EFO:0009108
# 20        cell size selection||FACS            EFO:0009337||EFO:0009108
# 21        cell size selection||FACS            EFO:0009337||EFO:0009108
# 22        cell size selection||FACS            EFO:0009337||EFO:0009108
# 23        cell size selection||FACS            EFO:0009337||EFO:0009108
# 24  density gradient centrifugation                         EFO:0009112
# 25        cell size selection||FACS            EFO:0009337||EFO:0009108
# 26        cell size selection||FACS            EFO:0009337||EFO:0009108
# 27  density gradient centrifugation                         EFO:0009112
# 28        cell size selection||FACS            EFO:0009337||EFO:0009108
#
#             enrichment_protocol.method.ontology_label  \
# 0   cell size selection||fluorescence-activated ce...
# 1                     density gradient centrifugation
# 2   cell size selection||fluorescence-activated ce...
# 3   cell size selection||fluorescence-activated ce...
# 4   cell size selection||fluorescence-activated ce...
# 5   cell size selection||fluorescence-activated ce...
# 6   cell size selection||fluorescence-activated ce...
# 7   cell size selection||fluorescence-activated ce...
# 8                     density gradient centrifugation
# 9   cell size selection||fluorescence-activated ce...
# 10  cell size selection||fluorescence-activated ce...
# 11  cell size selection||fluorescence-activated ce...
# 12  cell size selection||fluorescence-activated ce...
# 13  cell size selection||fluorescence-activated ce...
# 14  cell size selection||fluorescence-activated ce...
# 15  cell size selection||fluorescence-activated ce...
# 16  cell size selection||fluorescence-activated ce...
# 17  cell size selection||fluorescence-activated ce...
# 18  cell size selection||fluorescence-activated ce...
# 19  cell size selection||fluorescence-activated ce...
# 20  cell size selection||fluorescence-activated ce...
# 21  cell size selection||fluorescence-activated ce...
# 22  cell size selection||fluorescence-activated ce...
# 23  cell size selection||fluorescence-activated ce...
# 24                    density gradient centrifugation
# 25  cell size selection||fluorescence-activated ce...
# 26  cell size selection||fluorescence-activated ce...
# 27                    density gradient centrifugation
# 28  cell size selection||fluorescence-activated ce...
#
#    enrichment_protocol.maximum_size enrichment_protocol.markers  \
# 0                             100.0                       DAPI-
# 1                               NaN                         NaN
# 2                             100.0                       DAPI-
# 3                             100.0                       DAPI-
# 4                             100.0                       DAPI-
# 5                             100.0                       DAPI-
# 6                             100.0                       DAPI-
# 7                             100.0                       DAPI-
# 8                               NaN                         NaN
# 9                             100.0                       DAPI-
# 10                            100.0                       DAPI-
# 11                            100.0                       DAPI-
# 12                            100.0                       DAPI-
# 13                            100.0                       DAPI-
# 14                            100.0                       DAPI-
# 15                            100.0                       DAPI-
# 16                            100.0                       DAPI-
# 17                            100.0                       DAPI-
# 18                            100.0                       DAPI-
# 19                            100.0                       DAPI-
# 20                            100.0                       DAPI-
# 21                            100.0                       DAPI-
# 22                            100.0                       DAPI-
# 23                            100.0                       DAPI-
# 24                              NaN                         NaN
# 25                            100.0                       DAPI-
# 26                            100.0                       DAPI-
# 27                              NaN                         NaN
# 28                            100.0                       DAPI-
#
#    collection_protocol.protocol_core.protocol_name  \
# 0                       Kidney specimen collection
# 1                                       Blood draw
# 2                       Kidney specimen collection
# 3                       Kidney specimen collection
# 4                       Kidney specimen collection
# 5                       Kidney specimen collection
# 6                       Kidney specimen collection
# 7                       Kidney specimen collection
# 8                                       Blood draw
# 9                       Kidney specimen collection
# 10                      Kidney specimen collection
# 11                      Kidney specimen collection
# 12                      Kidney specimen collection
# 13                      Kidney specimen collection
# 14                      Kidney specimen collection
# 15                      Kidney specimen collection
# 16                      Kidney specimen collection
# 17                      Kidney specimen collection
# 18                      Kidney specimen collection
# 19                      Kidney specimen collection
# 20                      Kidney specimen collection
# 21                      Kidney specimen collection
# 22                           Lymph node collection
# 23                      Kidney specimen collection
# 24                                      Blood draw
# 25                      Kidney specimen collection
# 26                      Kidney specimen collection
# 27                                      Blood draw
# 28                      Kidney specimen collection
#
#    collection_protocol.protocol_core.protocol_description  \
# 0   Matching blood was collected in CPT tubes befo...
# 1   Samples were directly obtained from the operat...
# 2   Matching blood was collected in CPT tubes befo...
# 3   Matching blood was collected in CPT tubes befo...
# 4   Matching blood was collected in CPT tubes befo...
# 5   Matching blood was collected in CPT tubes befo...
# 6   Matching blood was collected in CPT tubes befo...
# 7   Matching blood was collected in CPT tubes befo...
# 8   Samples were directly obtained from the operat...
# 9   Matching blood was collected in CPT tubes befo...
# 10  Matching blood was collected in CPT tubes befo...
# 11  Matching blood was collected in CPT tubes befo...
# 12  Matching blood was collected in CPT tubes befo...
# 13  Matching blood was collected in CPT tubes befo...
# 14  Matching blood was collected in CPT tubes befo...
# 15  Matching blood was collected in CPT tubes befo...
# 16  Matching blood was collected in CPT tubes befo...
# 17  Matching blood was collected in CPT tubes befo...
# 18  Matching blood was collected in CPT tubes befo...
# 19  Matching blood was collected in CPT tubes befo...
# 20  Matching blood was collected in CPT tubes befo...
# 21  Matching blood was collected in CPT tubes befo...
# 22  Samples were directly obtained from the operat...
# 23  Matching blood was collected in CPT tubes befo...
# 24  Samples were directly obtained from the operat...
# 25  Matching blood was collected in CPT tubes befo...
# 26  Matching blood was collected in CPT tubes befo...
# 27  Samples were directly obtained from the operat...
# 28  Matching blood was collected in CPT tubes befo...
#
#    collection_protocol.method.text collection_protocol.method.ontology  \
# 0               surgical resection                         EFO:0009744
# 1                       blood draw                         EFO:0009121
# 2               surgical resection                         EFO:0009744
# 3               surgical resection                         EFO:0009744
# 4               surgical resection                         EFO:0009744
# 5               surgical resection                         EFO:0009744
# 6               surgical resection                         EFO:0009744
# 7               surgical resection                         EFO:0009744
# 8                       blood draw                         EFO:0009121
# 9               surgical resection                         EFO:0009744
# 10              surgical resection                         EFO:0009744
# 11              surgical resection                         EFO:0009744
# 12              surgical resection                         EFO:0009744
# 13              surgical resection                         EFO:0009744
# 14              surgical resection                         EFO:0009744
# 15              surgical resection                         EFO:0009744
# 16              surgical resection                         EFO:0009744
# 17              surgical resection                         EFO:0009744
# 18              surgical resection                         EFO:0009744
# 19              surgical resection                         EFO:0009744
# 20              surgical resection                         EFO:0009744
# 21              surgical resection                         EFO:0009744
# 22              surgical resection                         EFO:0009744
# 23              surgical resection                         EFO:0009744
# 24                      blood draw                         EFO:0009121
# 25              surgical resection                         EFO:0009744
# 26              surgical resection                         EFO:0009744
# 27                      blood draw                         EFO:0009121
# 28              surgical resection                         EFO:0009744
#
#    collection_protocol.method.ontology_label
# 0                         surgical resection
# 1                                 blood draw
# 2                         surgical resection
# 3                         surgical resection
# 4                         surgical resection
# 5                         surgical resection
# 6                         surgical resection
# 7                         surgical resection
# 8                                 blood draw
# 9                         surgical resection
# 10                        surgical resection
# 11                        surgical resection
# 12                        surgical resection
# 13                        surgical resection
# 14                        surgical resection
# 15                        surgical resection
# 16                        surgical resection
# 17                        surgical resection
# 18                        surgical resection
# 19                        surgical resection
# 20                        surgical resection
# 21                        surgical resection
# 22                        surgical resection
# 23                        surgical resection
# 24                                blood draw
# 25                        surgical resection
# 26                        surgical resection
# 27                                blood draw
# 28                        surgical resection
#
# [29 rows x 131 columns]

# %%
bc = bc.drop_duplicates(subset='cell_suspension.biomaterial_core.biomaterial_id')

# %%
bc.to_csv(os.path.join(flat_path, file_name.replace(".xlsx", "_flat_biomaterial.csv")), index = False)
