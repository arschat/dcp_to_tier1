# %% [markdown]
# # "Full Metadata" Spreadsheet (working title)
#
# See [ticket 576](https://app.zenhub.com/workspaces/dcp-ingest-product-development-5f71ca62a3cb47326bdc1b5c/issues/ebi-ait/dcp-ingest-central/576)
#
# This is an initial attempt for enabling data consumers to explore the metadata of an HCA project with common simple tools with minimal coding such as Excel Pivot Tables.

# %%
input_dir= './dcp_spreadsheets'
spreadsheet = f'{input_dir}/ImmuneLandscapeccRCC_metadata_30-01-2023.xlsx'
output_dir = './flat_dcp'
version = '0.7'

# %%
import fix_friendly_dcp_names

"""Convert generic friendly names (i.e. Protocol ID) to DCP friendly names (i.e. ENRICHMENT PROTOCOL (Required))"""
fix_friendly_dcp_names.fix_friendly_dcp_names(spreadsheet)
# Out:
# /Users/arsenios/Desktop/dcp_to_tier1/fix_friendly_dcp_names.py:11: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   dcp_template = pd.read_excel(hca_template_file, sheet_name=None, nrows=4, header=None)

# %%
import ipywidgets as widgets
from IPython.display import display
report_entity=None
report_entity_dropdown = widgets.Dropdown(
    options=['Sequence file', 'Image file', 'Analysis file'],
    value=report_entity or 'Analysis file',
    description='Report Entity:',
    disabled=False,
)
display(report_entity_dropdown)
# Out:
# Dropdown(description='Report Entity:', index=2, options=('Sequence file', 'Image file', 'Analysis file'), valu…

# %%
report_entity = report_entity_dropdown.value

# %% [markdown]
# * TODO: skip unnecessary lines
# * TODO: natural language column names vs variable names
# * DONE: render graph
# * DONE: analysis file linking
# * DONE: handle CSV fields (separated by ||)
# * TODO: analysis file -> imaged specimen <- image file
# * TODO: same for analysis file -> cell suspension <- sequence file
# * analysis file and image file are n:n relation

# %% [markdown]
# Define an Entity Relationship model (entity is a worksheet)

# %%
from dataclasses import dataclass

@dataclass
class SequencingProtocol:
    SEQUENCING_PROTOCOL_ID_Required: str

@dataclass
class LibraryPreparationProtocol:
    LIBRARY_PREPARATION_PROTOCOL_ID: str

@dataclass
class DissociationProtocol:
    DISSOCIATION_PROTOCOL_ID:str

@dataclass
class CollectionProtocol:
    COLLECTION_PROTOCOL_ID:str

@dataclass
class AnalysisProtocol:
    ANALYSIS_PROTOCOL_ID:str

@dataclass
class DifferentiationProtocol:
    DIFFERENTIATION_PROTOCOL_ID:str

@dataclass
class DonorOrganism:
    DONOR_ORGANISM_ID:str 

@dataclass
class SpecimenFromOrganism:
    SPECIMEN_FROM_ORGANISM_ID:str
    COLLECTION_PROTOCOL_ID:CollectionProtocol
    INPUT_DONOR_ORGANISM_ID:DonorOrganism

@dataclass
class EnrichmentProtocol:
    ENRICHMENT_PROTOCOL_ID:str

## CellLine added
@dataclass
class CellLine:
    CELL_LINE_ID: str
    ENRICHMENT_PROTOCOL_ID:EnrichmentProtocol
    DISSOCIATION_PROTOCOL_ID:DissociationProtocol
    INPUT_SPECIMEN_FROM_ORGANISM_ID:SpecimenFromOrganism

## Organoid Added
@dataclass
class Organoid:
    ORGANOID_ID: str
    INPUT_CELL_LINE_ID:CellLine
    INPUT_SPECIMEN_FROM_ORGANISM_ID:SpecimenFromOrganism
    DIFFERENTIATION_PROTOCOL_ID:DifferentiationProtocol

@dataclass
class CellSuspension:
    CELL_SUSPENSION_ID: str
    ENRICHMENT_PROTOCOL_ID:EnrichmentProtocol
    INPUT_SPECIMEN_FROM_ORGANISM_ID:SpecimenFromOrganism
    DISSOCIATION_PROTOCOL_ID:DissociationProtocol
    INPUT_SPECIMEN_FROM_ORGANISM_ID:SpecimenFromOrganism
    INPUT_ORGANOID_ID:Organoid
    INPUT_CELL_LINE_ID:CellLine

@dataclass
class SequenceFile:
    SEQUENCING_PROTOCOL_ID_Required: SequencingProtocol
    LIBRARY_PREPARATION_PROTOCOL_ID_Required: LibraryPreparationProtocol
    INPUT_CELL_SUSPENSION_ID_Required: CellSuspension


@dataclass
class ImagingPreparationProtocol:
    IMAGING_PREPARATION_PROTOCOL_ID:str


@dataclass
class ImagedSpecimen:
    IMAGED_SPECIMEN_ID_Required:str
    INPUT_SPECIMEN_FROM_ORGANISM_ID_Required:SpecimenFromOrganism
    IMAGING_PREPARATION_PROTOCOL_ID_Required:ImagingPreparationProtocol


@dataclass
class AnalysisFile:
    ANALYSIS_PROTOCOL_ID_Required: AnalysisProtocol
    IMAGED_SPECIMEN_ID_Required:ImagedSpecimen
    CELL_SUSPENSION_ID_Required:CellSuspension
    LIBRARY_PREPARATION_PROTOCOL_ID_Required:LibraryPreparationProtocol
    SEQUENCING_PROTOCOL_ID_Required:SequencingProtocol


@dataclass
class ImagingProtocol:
    IMAGING_PROTOCOL_ID:str

@dataclass
class ImageFile:
    INPUT_IMAGED_SPECIMEN_ID:ImagedSpecimen
    IMAGING_PROTOCOL_ID:ImagingProtocol

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import erdantic as erd
diagram = erd.create(AnalysisFile)
diagram
# Out:
# /var/folders/cg/kjj0b2v92rx2c4s4d0wc5by80000gp/T/ipykernel_63193/2241606415.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>
# EntityRelationshipDiagram(models=[DataClassModel(AnalysisFile), DataClassModel(AnalysisProtocol), DataClassModel(CellLine), DataClassModel(CellSuspension), DataClassModel(CollectionProtocol), DataClassModel(DifferentiationProtocol), DataClassModel(DissociationProtocol), DataClassModel(DonorOrganism), DataClassModel(EnrichmentProtocol), DataClassModel(ImagedSpecimen), DataClassModel(ImagingPreparationProtocol), DataClassModel(LibraryPreparationProtocol), DataClassModel(Organoid), DataClassModel(SequencingProtocol), DataClassModel(SpecimenFromOrganism)], edges=[Edge(source=DataClassModel(AnalysisFile), source_field=<DataClassField: 'ANALYSIS_PROTOCOL_ID_Required', AnalysisProtocol>, target=DataClassModel(AnalysisProtocol)), Edge(source=DataClassModel(AnalysisFile), source_field=<DataClassField: 'IMAGED_SPECIMEN_ID_Required', ImagedSpecimen>, target=DataClassModel(ImagedSpecimen)), Edge(source=DataClassModel(AnalysisFile), source_field=<DataClassField: 'CELL_SUSPENSION_ID_Required', CellSuspension>, target=DataClassModel(CellSuspension)), Edge(source=DataClassModel(AnalysisFile), source_field=<DataClassField: 'LIBRARY_PREPARATION_PROTOCOL_ID_Required', LibraryPreparationProtocol>, target=DataClassModel(LibraryPreparationProtocol)), Edge(source=DataClassModel(AnalysisFile), source_field=<DataClassField: 'SEQUENCING_PROTOCOL_ID_Required', SequencingProtocol>, target=DataClassModel(SequencingProtocol)), Edge(source=DataClassModel(CellLine), source_field=<DataClassField: 'ENRICHMENT_PROTOCOL_ID', EnrichmentProtocol>, target=DataClassModel(EnrichmentProtocol)), Edge(source=DataClassModel(CellLine), source_field=<DataClassField: 'DISSOCIATION_PROTOCOL_ID', DissociationProtocol>, target=DataClassModel(DissociationProtocol)), Edge(source=DataClassModel(CellLine), source_field=<DataClassField: 'INPUT_SPECIMEN_FROM_ORGANISM_ID', SpecimenFromOrganism>, target=DataClassModel(SpecimenFromOrganism)), Edge(source=DataClassModel(CellSuspension), source_field=<DataClassField: 'ENRICHMENT_PROTOCOL_ID', EnrichmentProtocol>, target=DataClassModel(EnrichmentProtocol)), Edge(source=DataClassModel(CellSuspension), source_field=<DataClassField: 'INPUT_SPECIMEN_FROM_ORGANISM_ID', SpecimenFromOrganism>, target=DataClassModel(SpecimenFromOrganism)), Edge(source=DataClassModel(CellSuspension), source_field=<DataClassField: 'DISSOCIATION_PROTOCOL_ID', DissociationProtocol>, target=DataClassModel(DissociationProtocol)), Edge(source=DataClassModel(CellSuspension), source_field=<DataClassField: 'INPUT_ORGANOID_ID', Organoid>, target=DataClassModel(Organoid)), Edge(source=DataClassModel(CellSuspension), source_field=<DataClassField: 'INPUT_CELL_LINE_ID', CellLine>, target=DataClassModel(CellLine)), Edge(source=DataClassModel(ImagedSpecimen), source_field=<DataClassField: 'INPUT_SPECIMEN_FROM_ORGANISM_ID_Required', SpecimenFromOrganism>, target=DataClassModel(SpecimenFromOrganism)), Edge(source=DataClassModel(ImagedSpecimen), source_field=<DataClassField: 'IMAGING_PREPARATION_PROTOCOL_ID_Required', ImagingPreparationProtocol>, target=DataClassModel(ImagingPreparationProtocol)), Edge(source=DataClassModel(Organoid), source_field=<DataClassField: 'INPUT_CELL_LINE_ID', CellLine>, target=DataClassModel(CellLine)), Edge(source=DataClassModel(Organoid), source_field=<DataClassField: 'INPUT_SPECIMEN_FROM_ORGANISM_ID', SpecimenFromOrganism>, target=DataClassModel(SpecimenFromOrganism)), Edge(source=DataClassModel(Organoid), source_field=<DataClassField: 'DIFFERENTIATION_PROTOCOL_ID', DifferentiationProtocol>, target=DataClassModel(DifferentiationProtocol)), Edge(source=DataClassModel(SpecimenFromOrganism), source_field=<DataClassField: 'COLLECTION_PROTOCOL_ID', CollectionProtocol>, target=DataClassModel(CollectionProtocol)), Edge(source=DataClassModel(SpecimenFromOrganism), source_field=<DataClassField: 'INPUT_DONOR_ORGANISM_ID', DonorOrganism>, target=DataClassModel(DonorOrganism))])

# %%
@dataclass
class Link:
    source:str
    target:str
    source_field:str
    target_field:str = None
    join_type:str = 'left'
    
        
    def __post_init__(self):
        if self.target_field is None:
            self.target_field = self.source_field
        else:
            print(f'{self.source}->{self.target} using fields {self.source_field}->{self.target_field}')
        
# TODO: links list is assumed to be topologically sorted, in the future - sort
links = [
#     Link('Image file', 'Imaged specimen', 'INPUT IMAGED SPECIMEN ID (Required)', 'IMAGED SPECIMEN ID (Required)'),
#     Link('Image file', 'Imaging protocol', 'IMAGING PROTOCOL ID (Required)'),
#     Link('Imaged specimen', 'Specimen from organism', 'INPUT SPECIMEN FROM ORGANISM ID (Required)', 'SPECIMEN FROM ORGANISM ID (Required)'),
#     Link('Imaged specimen', 'Imaging preparation protocol', 'IMAGING PREPARATION PROTOCOL ID (Required)'),

#     Link('Sequence file', 'Sequencing protocol', 'SEQUENCING PROTOCOL ID (Required)'),
#     Link('Sequence file','Library preparation protocol', 'LIBRARY PREPARATION PROTOCOL ID (Required)'),
#    Link('Sequence file', 'Cell suspension', 'INPUT CELL SUSPENSION ID (Required)','CELL SUSPENSION ID (Required)'),
    
    Link('Analysis file', 'Analysis protocol', 'ANALYSIS PROTOCOL ID (Required)', 'ANALYSIS PROTOCOL ID'),
    Link('Analysis file', 'Cell suspension', 'CELL SUSPENSION ID (Required)'),
    Link('Analysis file', 'Library preparation protocol', 'LIBRARY PREPARATION PROTOCOL ID (Required)'),
    Link('Analysis file', 'Sequencing protocol', 'SEQUENCING PROTOCOL ID (Required)'),
    
    # Link('Cell suspension', 'Organoid','INPUT ORGANOID ID (Required)','ORGANOID ID (Required)'),
    Link('Cell suspension', 'Specimen from organism','INPUT SPECIMEN FROM ORGANISM ID (Required)','SPECIMEN FROM ORGANISM ID (Required)'),
    Link('Cell suspension', 'Enrichment protocol','ENRICHMENT PROTOCOL ID (Required)'),
    Link('Cell suspension', 'Dissociation protocol','DISSOCIATION PROTOCOL ID (Required)'),
    
    # Link('Organoid', 'Cell line','INPUT CELL LINE ID (Required)','CELL LINE ID (Required)'),
    # Link('Organoid', 'Differentiation protocol','DIFFERENTIATION PROTOCOL ID (Required)', 'DIFFERENTIATION PROTOCOL ID (Required)'),
    # Link('Organoid', 'Specimen from organism','INPUT SPECIMEN FROM ORGANISM ID (Required)','SPECIMEN FROM ORGANISM ID (Required)'),
    
    # Link('Cell line', 'Specimen from organism','INPUT SPECIMEN FROM ORGANISM ID (Required)','SPECIMEN FROM ORGANISM ID (Required)'),
    # Link('Cell line', 'Enrichment protocol','ENRICHMENT PROTOCOL ID (Required)'),
    # Link('Cell line', 'Dissociation protocol','DISSOCIATION PROTOCOL ID (Required)'),
    
    Link('Specimen from organism', 'Collection protocol', 'COLLECTION PROTOCOL ID (Required)'),
    Link('Specimen from organism', 'Donor organism','INPUT DONOR ORGANISM ID (Required)','DONOR ORGANISM ID (Required)')#,
    
    
#     Link('Analysis file', 'Imaged specimen', 'IMAGED SPECIMEN ID (Required)'),    
#     Link('Imaged specimen', 'Analysis file', 'IMAGED SPECIMEN ID (Required)', join_type='left')
        
]
# Out:
# Analysis file->Analysis protocol using fields ANALYSIS PROTOCOL ID (Required)->ANALYSIS PROTOCOL ID
# Cell suspension->Specimen from organism using fields INPUT SPECIMEN FROM ORGANISM ID (Required)->SPECIMEN FROM ORGANISM ID (Required)
# Specimen from organism->Donor organism using fields INPUT DONOR ORGANISM ID (Required)->DONOR ORGANISM ID (Required)

# %%
import networkx as nx
import matplotlib.pyplot as plt
from functools import partial


# %matplotlib inline


def add_link_to_graph(graph :nx.Graph, link :Link):
    map(graph.add_node, filter(lambda node:node not in graph.nodes, [link.source, link.target] ))
    graph.add_edge(link.source, link.target, keys=f'{link.source_field}\n->{link.target_field}')

G = nx.Graph()
x =list(map(partial(add_link_to_graph, G), links))

fig = plt.figure()
plt.figure(figsize=(16, 10))

labels = nx.get_edge_attributes(G, 'keys')
pos = nx.spring_layout(G)          
nx.draw_networkx(G, pos, arrowstyle="->",)
nx.draw_networkx_edge_labels(G, pos, labels, font_size=10)
# Out:
# /Users/arsenios/Desktop/dcp_to_tier1/.venv/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:312: UserWarning:
#
# The arrowstyle keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default values.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
# {('Analysis file',
#   'Analysis protocol'): Text(0.3298837705046269, -0.6688647098248152, 'ANALYSIS PROTOCOL ID (Required)\n->ANALYSIS PROTOCOL ID'),
#  ('Analysis file',
#   'Cell suspension'): Text(0.09340197673219386, -0.2081442046535127, 'CELL SUSPENSION ID (Required)\n->CELL SUSPENSION ID (Required)'),
#  ('Analysis file',
#   'Library preparation protocol'): Text(0.13324412355411286, -0.6578175022050124, 'LIBRARY PREPARATION PROTOCOL ID (Required)\n->LIBRARY PREPARATION PROTOCOL ID (Required)'),
#  ('Analysis file',
#   'Sequencing protocol'): Text(0.4342201452954424, -0.5033532910162241, 'SEQUENCING PROTOCOL ID (Required)\n->SEQUENCING PROTOCOL ID (Required)'),
#  ('Cell suspension',
#   'Specimen from organism'): Text(-0.1654929616158224, 0.32935339060959645, 'INPUT SPECIMEN FROM ORGANISM ID (Required)\n->SPECIMEN FROM ORGANISM ID (Required)'),
#  ('Cell suspension',
#   'Enrichment protocol'): Text(-0.22821970976644768, 0.006190811326032941, 'ENRICHMENT PROTOCOL ID (Required)\n->ENRICHMENT PROTOCOL ID (Required)'),
#  ('Cell suspension',
#   'Dissociation protocol'): Text(0.10851928427149504, 0.167849233351838, 'DISSOCIATION PROTOCOL ID (Required)\n->DISSOCIATION PROTOCOL ID (Required)'),
#  ('Specimen from organism',
#   'Collection protocol'): Text(-0.45370088751349524, 0.7073851515217449, 'COLLECTION PROTOCOL ID (Required)\n->COLLECTION PROTOCOL ID (Required)'),
#  ('Specimen from organism',
#   'Donor organism'): Text(-0.25660801029393765, 0.7970341424074316, 'INPUT DONOR ORGANISM ID (Required)\n->DONOR ORGANISM ID (Required)')}

# %%
import pandas as pd
sep='\\|\\|'
def explode_csv_col(df :pd.DataFrame, column :str, sep=',') -> pd.DataFrame:
    cols={}
    cols[column] = df[column].str.split(sep)
    return df.assign(**cols).explode(column)

def format_column_name(column_name, namespace):
    return f'{namespace}_{column_name}'

def prefix_columns(df, prefix):
    return df.rename(columns=lambda c:format_column_name(namespace=prefix,column_name=c))

first_data_line=4
def remove_field_desc_lines(df:pd.DataFrame) -> pd.DataFrame:
    return df[first_data_line:]

def merge_multiple_entities(worksheet:pd.DataFrame,
                            target:pd.DataFrame, 
                            source_field:str, 
                            target_field:str, 
                            link:Link):
    # Perform merge operation
    result = pd.merge(worksheet, target, how=link.join_type, left_on=source_field, right_on=target_field, suffixes=(None, '_y'))
    
    # Identify duplicated columns
    duplicated_cols = [col for col in result.columns if col.endswith('_y')]
    overwriting_cols = [x.strip('_y') for x in duplicated_cols]

    # Check for conflicts between columns
    result_na_none = result[overwriting_cols].dropna(how='all')
    result_na_y = result[duplicated_cols].dropna(how='all')

    # exclude case a field is derived from different tabs
    # (i.e. one cell suspension from organoid AND specimen)
    # for selected columns, values should either everything na, or None or _y should be na
    # If there are conflicts, print a message and drop duplicate columns
    if not result_na_y.index.intersection(result_na_none.index).empty:
        print(f'Multiple {link.target} for the same element. Will skip {link.target} from {link.source}')
        result = result.drop(columns=duplicated_cols)
    else:
        # If no conflicts, fill NaN values with values from duplicate columns and drop source_field
        result = result.drop(columns=duplicated_cols).fillna(result_na_y.rename(columns=lambda x: x.strip('_y')))
        result.drop(columns=source_field, inplace=True)

    return result

# %%
from datetime import datetime
now = lambda : datetime.now().strftime('%H%M%S.%f')

import os
def join_worksheet(worksheet:pd.DataFrame, 
                   link:Link, 
                   spreadsheet:str) -> pd.DataFrame:
    print(f'joining [{link.source}] to [{link.target}]')
    print(f'fields [{link.source_field}] and [{link.target_field}]')
    try:
        source_field = format_column_name(column_name=link.source_field, namespace=link.source)
        target_field = format_column_name(column_name=link.target_field, namespace=link.target)
        worksheet = explode_csv_col(df=worksheet, column=source_field, sep=sep)
    
        spreadsheet_obj = pd.ExcelFile(spreadsheet)
        if link.target not in spreadsheet_obj.sheet_names:
            raise ValueError(f'spreadsheet does not contain {link.target} sheet. Possible names {sorted(spreadsheet_obj.sheet_names)}')
        target = spreadsheet_obj.parse(link.target)
    
        target = pd.read_excel(spreadsheet, link.target)
        target = remove_field_desc_lines(target)
        target = prefix_columns(target, prefix=link.target)
    
        target = explode_csv_col(target, column=target_field, sep=sep)
    
        if target_field in worksheet.columns:
            result = merge_multiple_entities(worksheet, target, source_field, target_field, link)

        else:
            result = worksheet.merge(target, 
                                    how=link.join_type, 
                                    left_on=source_field, 
                                    right_on=target_field)
            result.drop(columns=source_field, inplace= True)
        
        print(f'record count: original {len(worksheet)}, joined {len(result)}')
        if len(result.index) == 0:
            raise RuntimeError('problem joining [{link.source}] to [{link.target}] using fields [{source_field}] and [{target_field}]: join resulted in zero rows')
        
    except KeyError as e:
        err_msg = f'problem joining [{link.source}] to [{link.target}] using fields [{source_field}] and [{target_field}]: {e}'
        raise RuntimeError(err_msg) from e
    return result

# %%
import pandas as pd
from collections import namedtuple
from functools import partial, reduce

def flatten_spreadsheet(spreadsheet, report_entity):
    spreadsheet_obj = pd.ExcelFile(spreadsheet)
    if report_entity not in spreadsheet_obj.sheet_names:
        raise ValueError(f'spreadsheet does not contain {report_entity} sheet')
    report_sheet = spreadsheet_obj.parse(report_entity)
    report_sheet = prefix_columns(report_sheet, prefix=report_entity)
    report_sheet = remove_field_desc_lines(report_sheet)
    flattened = reduce(partial(join_worksheet, spreadsheet=spreadsheet), 
                       links,
                       report_sheet)
    return flattened

flattened = flatten_spreadsheet(spreadsheet, report_entity)

# remove empty columns
flattened.dropna(axis='columns',how='all', inplace=True)

# add project label
project_info = pd.read_excel(spreadsheet, 'Project')
data_row_idx = 4
project_label = project_info['PROJECT LABEL (Required)'][data_row_idx]
flattened['project_label'] = project_label

# use ingest attribute names as columns
spreadsheet_obj = pd.ExcelFile(spreadsheet)
for column in flattened.columns:
    tab, original_column = column.split('_')
    if tab not in spreadsheet_obj.sheet_names:
        continue
    tab_df = spreadsheet_obj.parse(tab)
    data_row_idx = 2
    ingest_attribute_name = tab_df[original_column][data_row_idx]
    if ingest_attribute_name not in flattened.columns:
        if ingest_attribute_name == 'specimen_from_organism.biomaterial_core.biomaterial_id':
            print(column)
        flattened.rename(columns={column:ingest_attribute_name}, inplace=True)
    else:
        flattened.drop(labels=column, axis='columns', inplace=True)
# Out:
# joining [Analysis file] to [Analysis protocol]
# fields [ANALYSIS PROTOCOL ID (Required)] and [ANALYSIS PROTOCOL ID]
# record count: original 3, joined 3
# joining [Analysis file] to [Cell suspension]
# fields [CELL SUSPENSION ID (Required)] and [CELL SUSPENSION ID (Required)]
# record count: original 87, joined 87
# joining [Analysis file] to [Library preparation protocol]
# fields [LIBRARY PREPARATION PROTOCOL ID (Required)] and [LIBRARY PREPARATION PROTOCOL ID (Required)]
# record count: original 87, joined 87
# joining [Analysis file] to [Sequencing protocol]
# fields [SEQUENCING PROTOCOL ID (Required)] and [SEQUENCING PROTOCOL ID (Required)]
# record count: original 87, joined 87
# joining [Cell suspension] to [Specimen from organism]
# fields [INPUT SPECIMEN FROM ORGANISM ID (Required)] and [SPECIMEN FROM ORGANISM ID (Required)]
# record count: original 87, joined 87
# joining [Cell suspension] to [Enrichment protocol]
# fields [ENRICHMENT PROTOCOL ID (Required)] and [ENRICHMENT PROTOCOL ID (Required)]
# record count: original 162, joined 162
# joining [Cell suspension] to [Dissociation protocol]
# fields [DISSOCIATION PROTOCOL ID (Required)] and [DISSOCIATION PROTOCOL ID (Required)]
# record count: original 312, joined 312
# joining [Specimen from organism] to [Collection protocol]
# fields [COLLECTION PROTOCOL ID (Required)] and [COLLECTION PROTOCOL ID (Required)]
# record count: original 312, joined 312
# joining [Specimen from organism] to [Donor organism]
# fields [INPUT DONOR ORGANISM ID (Required)] and [DONOR ORGANISM ID (Required)]
# record count: original 312, joined 312
# Specimen from organism_SPECIMEN FROM ORGANISM ID (Required)

# %%
flattened.columns
# Out:
# Index(['analysis_file.uuid', 'analysis_file.file_core.file_name',
#        'analysis_file.file_core.format',
#        'analysis_file.file_core.content_description.text',
#        'analysis_file.file_core.content_description.ontology',
#        'analysis_file.file_core.content_description.ontology_label',
#        'analysis_file.file_core.file_source',
#        'analysis_file.matrix_cell_count',
#        'analysis_file.genome_assembly_version', 'process.uuid',
#        ...
#        'donor_organism.organism_age_unit.ontology_label',
#        'donor_organism.development_stage.text',
#        'donor_organism.development_stage.ontology',
#        'donor_organism.development_stage.ontology_label',
#        'donor_organism.diseases.text', 'donor_organism.diseases.ontology',
#        'donor_organism.diseases.ontology_label',
#        'donor_organism.medical_history.treatment',
#        'donor_organism.medical_history.medication', 'project_label'],
#       dtype='object', length=132)

# %%
def collapse_values(series):
    return "||".join(series.unique().astype(str))

flattened.groupby('specimen_from_organism.biomaterial_core.biomaterial_id').agg(collapse_values).dropna(axis=1, how='all')
# Out:
#                                                                                    analysis_file.uuid  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Complete_kidney                             943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Complete_tumor_Center                       943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Complete_tumor_Far                          943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Complete_tumor_Near                         943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Mixed_PBMC                                  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Mixed_kidney                                943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Mixed_tumor_Center                          943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Mixed_tumor_Far                             943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Mixed_tumor_Near                            943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Resistant_PBMC                              943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Resistant_kidney                            943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Resistant_lymph_node                        943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Resistant_tumor_Center                      943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Resistant_tumor_Far                         943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# IpiNivo_Resistant_tumor_Near                        943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# NivoExposed_PBMC                                    943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# NivoExposed_kidney                                  943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# NivoExposed_tumor_Center                            943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# NivoExposed_tumor_Far                               943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# NivoExposed_tumor_Near                              943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT1_kidney                                          943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT1_tumor_Center                                    943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT1_tumor_Far                                       943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT1_tumor_Near                                      943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT2_kidney                                          943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT2_tumor_Center                                    943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT2_tumor_Far                                       943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
# UT2_tumor_Near                                      943cffb4-e61a-4858-9b9c-f9fcdcb7ac0f||d7a4b189...
#
#                                                                     analysis_file.file_core.file_name  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Complete_kidney                             ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Complete_tumor_Center                       ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Complete_tumor_Far                          ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Complete_tumor_Near                         ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Mixed_PBMC                                  ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Mixed_kidney                                ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Mixed_tumor_Center                          ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Mixed_tumor_Far                             ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Mixed_tumor_Near                            ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Resistant_PBMC                              ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Resistant_kidney                            ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Resistant_lymph_node                        ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Resistant_tumor_Center                      ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Resistant_tumor_Far                         ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# IpiNivo_Resistant_tumor_Near                        ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# NivoExposed_PBMC                                    ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# NivoExposed_kidney                                  ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# NivoExposed_tumor_Center                            ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# NivoExposed_tumor_Far                               ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# NivoExposed_tumor_Near                              ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT1_kidney                                          ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT1_tumor_Center                                    ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT1_tumor_Far                                       ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT1_tumor_Near                                      ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT2_kidney                                          ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT2_tumor_Center                                    ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT2_tumor_Far                                       ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
# UT2_tumor_Near                                      ccRCC_6pat_Seurat.rds||ccRCC_6pat_cell_annotat...
#
#                                                    analysis_file.file_core.format  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                    rds||txt
# IpiNivo_Complete_kidney                                                  rds||txt
# IpiNivo_Complete_tumor_Center                                            rds||txt
# IpiNivo_Complete_tumor_Far                                               rds||txt
# IpiNivo_Complete_tumor_Near                                              rds||txt
# IpiNivo_Mixed_PBMC                                                       rds||txt
# IpiNivo_Mixed_kidney                                                     rds||txt
# IpiNivo_Mixed_tumor_Center                                               rds||txt
# IpiNivo_Mixed_tumor_Far                                                  rds||txt
# IpiNivo_Mixed_tumor_Near                                                 rds||txt
# IpiNivo_Resistant_PBMC                                                   rds||txt
# IpiNivo_Resistant_kidney                                                 rds||txt
# IpiNivo_Resistant_lymph_node                                             rds||txt
# IpiNivo_Resistant_tumor_Center                                           rds||txt
# IpiNivo_Resistant_tumor_Far                                              rds||txt
# IpiNivo_Resistant_tumor_Near                                             rds||txt
# NivoExposed_PBMC                                                         rds||txt
# NivoExposed_kidney                                                       rds||txt
# NivoExposed_tumor_Center                                                 rds||txt
# NivoExposed_tumor_Far                                                    rds||txt
# NivoExposed_tumor_Near                                                   rds||txt
# UT1_kidney                                                               rds||txt
# UT1_tumor_Center                                                         rds||txt
# UT1_tumor_Far                                                            rds||txt
# UT1_tumor_Near                                                           rds||txt
# UT2_kidney                                                               rds||txt
# UT2_tumor_Center                                                         rds||txt
# UT2_tumor_Far                                                            rds||txt
# UT2_tumor_Near                                                           rds||txt
#
#                                                      analysis_file.file_core.content_description.text  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               count matrix||cell type||sample annotation||TC...
# IpiNivo_Complete_kidney                             count matrix||cell type||sample annotation||TC...
# IpiNivo_Complete_tumor_Center                       count matrix||cell type||sample annotation||TC...
# IpiNivo_Complete_tumor_Far                          count matrix||cell type||sample annotation||TC...
# IpiNivo_Complete_tumor_Near                         count matrix||cell type||sample annotation||TC...
# IpiNivo_Mixed_PBMC                                  count matrix||cell type||sample annotation||TC...
# IpiNivo_Mixed_kidney                                count matrix||cell type||sample annotation||TC...
# IpiNivo_Mixed_tumor_Center                          count matrix||cell type||sample annotation||TC...
# IpiNivo_Mixed_tumor_Far                             count matrix||cell type||sample annotation||TC...
# IpiNivo_Mixed_tumor_Near                            count matrix||cell type||sample annotation||TC...
# IpiNivo_Resistant_PBMC                              count matrix||cell type||sample annotation||TC...
# IpiNivo_Resistant_kidney                            count matrix||cell type||sample annotation||TC...
# IpiNivo_Resistant_lymph_node                        count matrix||cell type||sample annotation||TC...
# IpiNivo_Resistant_tumor_Center                      count matrix||cell type||sample annotation||TC...
# IpiNivo_Resistant_tumor_Far                         count matrix||cell type||sample annotation||TC...
# IpiNivo_Resistant_tumor_Near                        count matrix||cell type||sample annotation||TC...
# NivoExposed_PBMC                                    count matrix||cell type||sample annotation||TC...
# NivoExposed_kidney                                  count matrix||cell type||sample annotation||TC...
# NivoExposed_tumor_Center                            count matrix||cell type||sample annotation||TC...
# NivoExposed_tumor_Far                               count matrix||cell type||sample annotation||TC...
# NivoExposed_tumor_Near                              count matrix||cell type||sample annotation||TC...
# UT1_kidney                                          count matrix||cell type||sample annotation||TC...
# UT1_tumor_Center                                    count matrix||cell type||sample annotation||TC...
# UT1_tumor_Far                                       count matrix||cell type||sample annotation||TC...
# UT1_tumor_Near                                      count matrix||cell type||sample annotation||TC...
# UT2_kidney                                          count matrix||cell type||sample annotation||TC...
# UT2_tumor_Center                                    count matrix||cell type||sample annotation||TC...
# UT2_tumor_Far                                       count matrix||cell type||sample annotation||TC...
# UT2_tumor_Near                                      count matrix||cell type||sample annotation||TC...
#
#                                                    analysis_file.file_core.content_description.ontology  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                            data:3917||data:2892||data:3113||nan
# IpiNivo_Complete_kidney                                          data:3917||data:2892||data:3113||nan
# IpiNivo_Complete_tumor_Center                                    data:3917||data:2892||data:3113||nan
# IpiNivo_Complete_tumor_Far                                       data:3917||data:2892||data:3113||nan
# IpiNivo_Complete_tumor_Near                                      data:3917||data:2892||data:3113||nan
# IpiNivo_Mixed_PBMC                                               data:3917||data:2892||data:3113||nan
# IpiNivo_Mixed_kidney                                             data:3917||data:2892||data:3113||nan
# IpiNivo_Mixed_tumor_Center                                       data:3917||data:2892||data:3113||nan
# IpiNivo_Mixed_tumor_Far                                          data:3917||data:2892||data:3113||nan
# IpiNivo_Mixed_tumor_Near                                         data:3917||data:2892||data:3113||nan
# IpiNivo_Resistant_PBMC                                           data:3917||data:2892||data:3113||nan
# IpiNivo_Resistant_kidney                                         data:3917||data:2892||data:3113||nan
# IpiNivo_Resistant_lymph_node                                     data:3917||data:2892||data:3113||nan
# IpiNivo_Resistant_tumor_Center                                   data:3917||data:2892||data:3113||nan
# IpiNivo_Resistant_tumor_Far                                      data:3917||data:2892||data:3113||nan
# IpiNivo_Resistant_tumor_Near                                     data:3917||data:2892||data:3113||nan
# NivoExposed_PBMC                                                 data:3917||data:2892||data:3113||nan
# NivoExposed_kidney                                               data:3917||data:2892||data:3113||nan
# NivoExposed_tumor_Center                                         data:3917||data:2892||data:3113||nan
# NivoExposed_tumor_Far                                            data:3917||data:2892||data:3113||nan
# NivoExposed_tumor_Near                                           data:3917||data:2892||data:3113||nan
# UT1_kidney                                                       data:3917||data:2892||data:3113||nan
# UT1_tumor_Center                                                 data:3917||data:2892||data:3113||nan
# UT1_tumor_Far                                                    data:3917||data:2892||data:3113||nan
# UT1_tumor_Near                                                   data:3917||data:2892||data:3113||nan
# UT2_kidney                                                       data:3917||data:2892||data:3113||nan
# UT2_tumor_Center                                                 data:3917||data:2892||data:3113||nan
# UT2_tumor_Far                                                    data:3917||data:2892||data:3113||nan
# UT2_tumor_Near                                                   data:3917||data:2892||data:3113||nan
#
#                                                    analysis_file.file_core.content_description.ontology_label  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Complete_kidney                             Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Complete_tumor_Center                       Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Complete_tumor_Far                          Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Complete_tumor_Near                         Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Mixed_PBMC                                  Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Mixed_kidney                                Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Mixed_tumor_Center                          Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Mixed_tumor_Far                             Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Mixed_tumor_Near                            Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Resistant_PBMC                              Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Resistant_kidney                            Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Resistant_lymph_node                        Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Resistant_tumor_Center                      Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Resistant_tumor_Far                         Count matrix||Cell type name||Sample annotatio...
# IpiNivo_Resistant_tumor_Near                        Count matrix||Cell type name||Sample annotatio...
# NivoExposed_PBMC                                    Count matrix||Cell type name||Sample annotatio...
# NivoExposed_kidney                                  Count matrix||Cell type name||Sample annotatio...
# NivoExposed_tumor_Center                            Count matrix||Cell type name||Sample annotatio...
# NivoExposed_tumor_Far                               Count matrix||Cell type name||Sample annotatio...
# NivoExposed_tumor_Near                              Count matrix||Cell type name||Sample annotatio...
# UT1_kidney                                          Count matrix||Cell type name||Sample annotatio...
# UT1_tumor_Center                                    Count matrix||Cell type name||Sample annotatio...
# UT1_tumor_Far                                       Count matrix||Cell type name||Sample annotatio...
# UT1_tumor_Near                                      Count matrix||Cell type name||Sample annotatio...
# UT2_kidney                                          Count matrix||Cell type name||Sample annotatio...
# UT2_tumor_Center                                    Count matrix||Cell type name||Sample annotatio...
# UT2_tumor_Far                                       Count matrix||Cell type name||Sample annotatio...
# UT2_tumor_Near                                      Count matrix||Cell type name||Sample annotatio...
#
#                                                    analysis_file.file_core.file_source  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                      Publication
# IpiNivo_Complete_kidney                                                    Publication
# IpiNivo_Complete_tumor_Center                                              Publication
# IpiNivo_Complete_tumor_Far                                                 Publication
# IpiNivo_Complete_tumor_Near                                                Publication
# IpiNivo_Mixed_PBMC                                                         Publication
# IpiNivo_Mixed_kidney                                                       Publication
# IpiNivo_Mixed_tumor_Center                                                 Publication
# IpiNivo_Mixed_tumor_Far                                                    Publication
# IpiNivo_Mixed_tumor_Near                                                   Publication
# IpiNivo_Resistant_PBMC                                                     Publication
# IpiNivo_Resistant_kidney                                                   Publication
# IpiNivo_Resistant_lymph_node                                               Publication
# IpiNivo_Resistant_tumor_Center                                             Publication
# IpiNivo_Resistant_tumor_Far                                                Publication
# IpiNivo_Resistant_tumor_Near                                               Publication
# NivoExposed_PBMC                                                           Publication
# NivoExposed_kidney                                                         Publication
# NivoExposed_tumor_Center                                                   Publication
# NivoExposed_tumor_Far                                                      Publication
# NivoExposed_tumor_Near                                                     Publication
# UT1_kidney                                                                 Publication
# UT1_tumor_Center                                                           Publication
# UT1_tumor_Far                                                              Publication
# UT1_tumor_Near                                                             Publication
# UT2_kidney                                                                 Publication
# UT2_tumor_Center                                                           Publication
# UT2_tumor_Far                                                              Publication
# UT2_tumor_Near                                                             Publication
#
#                                                    analysis_file.matrix_cell_count  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                  167283||nan
# IpiNivo_Complete_kidney                                                167283||nan
# IpiNivo_Complete_tumor_Center                                          167283||nan
# IpiNivo_Complete_tumor_Far                                             167283||nan
# IpiNivo_Complete_tumor_Near                                            167283||nan
# IpiNivo_Mixed_PBMC                                                     167283||nan
# IpiNivo_Mixed_kidney                                                   167283||nan
# IpiNivo_Mixed_tumor_Center                                             167283||nan
# IpiNivo_Mixed_tumor_Far                                                167283||nan
# IpiNivo_Mixed_tumor_Near                                               167283||nan
# IpiNivo_Resistant_PBMC                                                 167283||nan
# IpiNivo_Resistant_kidney                                               167283||nan
# IpiNivo_Resistant_lymph_node                                           167283||nan
# IpiNivo_Resistant_tumor_Center                                         167283||nan
# IpiNivo_Resistant_tumor_Far                                            167283||nan
# IpiNivo_Resistant_tumor_Near                                           167283||nan
# NivoExposed_PBMC                                                       167283||nan
# NivoExposed_kidney                                                     167283||nan
# NivoExposed_tumor_Center                                               167283||nan
# NivoExposed_tumor_Far                                                  167283||nan
# NivoExposed_tumor_Near                                                 167283||nan
# UT1_kidney                                                             167283||nan
# UT1_tumor_Center                                                       167283||nan
# UT1_tumor_Far                                                          167283||nan
# UT1_tumor_Near                                                         167283||nan
# UT2_kidney                                                             167283||nan
# UT2_tumor_Center                                                       167283||nan
# UT2_tumor_Far                                                          167283||nan
# UT2_tumor_Near                                                         167283||nan
#
#                                                    analysis_file.genome_assembly_version  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                     GRCh37||GRCh38
# IpiNivo_Complete_kidney                                                   GRCh37||GRCh38
# IpiNivo_Complete_tumor_Center                                             GRCh37||GRCh38
# IpiNivo_Complete_tumor_Far                                                GRCh37||GRCh38
# IpiNivo_Complete_tumor_Near                                               GRCh37||GRCh38
# IpiNivo_Mixed_PBMC                                                        GRCh37||GRCh38
# IpiNivo_Mixed_kidney                                                      GRCh37||GRCh38
# IpiNivo_Mixed_tumor_Center                                                GRCh37||GRCh38
# IpiNivo_Mixed_tumor_Far                                                   GRCh37||GRCh38
# IpiNivo_Mixed_tumor_Near                                                  GRCh37||GRCh38
# IpiNivo_Resistant_PBMC                                                    GRCh37||GRCh38
# IpiNivo_Resistant_kidney                                                  GRCh37||GRCh38
# IpiNivo_Resistant_lymph_node                                              GRCh37||GRCh38
# IpiNivo_Resistant_tumor_Center                                            GRCh37||GRCh38
# IpiNivo_Resistant_tumor_Far                                               GRCh37||GRCh38
# IpiNivo_Resistant_tumor_Near                                              GRCh37||GRCh38
# NivoExposed_PBMC                                                          GRCh37||GRCh38
# NivoExposed_kidney                                                        GRCh37||GRCh38
# NivoExposed_tumor_Center                                                  GRCh37||GRCh38
# NivoExposed_tumor_Far                                                     GRCh37||GRCh38
# NivoExposed_tumor_Near                                                    GRCh37||GRCh38
# UT1_kidney                                                                GRCh37||GRCh38
# UT1_tumor_Center                                                          GRCh37||GRCh38
# UT1_tumor_Far                                                             GRCh37||GRCh38
# UT1_tumor_Near                                                            GRCh37||GRCh38
# UT2_kidney                                                                GRCh37||GRCh38
# UT2_tumor_Center                                                          GRCh37||GRCh38
# UT2_tumor_Far                                                             GRCh37||GRCh38
# UT2_tumor_Near                                                            GRCh37||GRCh38
#
#                                                                                          process.uuid  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Complete_kidney                             42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Complete_tumor_Center                       42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Complete_tumor_Far                          42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Complete_tumor_Near                         42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Mixed_PBMC                                  42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Mixed_kidney                                42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Mixed_tumor_Center                          42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Mixed_tumor_Far                             42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Mixed_tumor_Near                            42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Resistant_PBMC                              42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Resistant_kidney                            42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Resistant_lymph_node                        42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Resistant_tumor_Center                      42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Resistant_tumor_Far                         42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# IpiNivo_Resistant_tumor_Near                        42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# NivoExposed_PBMC                                    42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# NivoExposed_kidney                                  42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# NivoExposed_tumor_Center                            42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# NivoExposed_tumor_Far                               42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# NivoExposed_tumor_Near                              42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT1_kidney                                          42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT1_tumor_Center                                    42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT1_tumor_Far                                       42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT1_tumor_Near                                      42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT2_kidney                                          42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT2_tumor_Center                                    42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT2_tumor_Far                                       42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
# UT2_tumor_Near                                      42c76920-ebba-4b9d-a410-d70b97df1af2||24133154...
#
#                                                     ...  \
# specimen_from_organism.biomaterial_core.biomate...  ...
# IpiNivo_Complete_PBMC                               ...
# IpiNivo_Complete_kidney                             ...
# IpiNivo_Complete_tumor_Center                       ...
# IpiNivo_Complete_tumor_Far                          ...
# IpiNivo_Complete_tumor_Near                         ...
# IpiNivo_Mixed_PBMC                                  ...
# IpiNivo_Mixed_kidney                                ...
# IpiNivo_Mixed_tumor_Center                          ...
# IpiNivo_Mixed_tumor_Far                             ...
# IpiNivo_Mixed_tumor_Near                            ...
# IpiNivo_Resistant_PBMC                              ...
# IpiNivo_Resistant_kidney                            ...
# IpiNivo_Resistant_lymph_node                        ...
# IpiNivo_Resistant_tumor_Center                      ...
# IpiNivo_Resistant_tumor_Far                         ...
# IpiNivo_Resistant_tumor_Near                        ...
# NivoExposed_PBMC                                    ...
# NivoExposed_kidney                                  ...
# NivoExposed_tumor_Center                            ...
# NivoExposed_tumor_Far                               ...
# NivoExposed_tumor_Near                              ...
# UT1_kidney                                          ...
# UT1_tumor_Center                                    ...
# UT1_tumor_Far                                       ...
# UT1_tumor_Near                                      ...
# UT2_kidney                                          ...
# UT2_tumor_Center                                    ...
# UT2_tumor_Far                                       ...
# UT2_tumor_Near                                      ...
#
#                                                    donor_organism.organism_age_unit.ontology_label  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                                         year
# IpiNivo_Complete_kidney                                                                       year
# IpiNivo_Complete_tumor_Center                                                                 year
# IpiNivo_Complete_tumor_Far                                                                    year
# IpiNivo_Complete_tumor_Near                                                                   year
# IpiNivo_Mixed_PBMC                                                                            year
# IpiNivo_Mixed_kidney                                                                          year
# IpiNivo_Mixed_tumor_Center                                                                    year
# IpiNivo_Mixed_tumor_Far                                                                       year
# IpiNivo_Mixed_tumor_Near                                                                      year
# IpiNivo_Resistant_PBMC                                                                        year
# IpiNivo_Resistant_kidney                                                                      year
# IpiNivo_Resistant_lymph_node                                                                  year
# IpiNivo_Resistant_tumor_Center                                                                year
# IpiNivo_Resistant_tumor_Far                                                                   year
# IpiNivo_Resistant_tumor_Near                                                                  year
# NivoExposed_PBMC                                                                              year
# NivoExposed_kidney                                                                            year
# NivoExposed_tumor_Center                                                                      year
# NivoExposed_tumor_Far                                                                         year
# NivoExposed_tumor_Near                                                                        year
# UT1_kidney                                                                                    year
# UT1_tumor_Center                                                                              year
# UT1_tumor_Far                                                                                 year
# UT1_tumor_Near                                                                                year
# UT2_kidney                                                                                    year
# UT2_tumor_Center                                                                              year
# UT2_tumor_Far                                                                                 year
# UT2_tumor_Near                                                                                year
#
#                                                    donor_organism.development_stage.text  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                  adult human stage
# IpiNivo_Complete_kidney                                                adult human stage
# IpiNivo_Complete_tumor_Center                                          adult human stage
# IpiNivo_Complete_tumor_Far                                             adult human stage
# IpiNivo_Complete_tumor_Near                                            adult human stage
# IpiNivo_Mixed_PBMC                                                     adult human stage
# IpiNivo_Mixed_kidney                                                   adult human stage
# IpiNivo_Mixed_tumor_Center                                             adult human stage
# IpiNivo_Mixed_tumor_Far                                                adult human stage
# IpiNivo_Mixed_tumor_Near                                               adult human stage
# IpiNivo_Resistant_PBMC                                                 adult human stage
# IpiNivo_Resistant_kidney                                               adult human stage
# IpiNivo_Resistant_lymph_node                                           adult human stage
# IpiNivo_Resistant_tumor_Center                                         adult human stage
# IpiNivo_Resistant_tumor_Far                                            adult human stage
# IpiNivo_Resistant_tumor_Near                                           adult human stage
# NivoExposed_PBMC                                                       adult human stage
# NivoExposed_kidney                                                     adult human stage
# NivoExposed_tumor_Center                                               adult human stage
# NivoExposed_tumor_Far                                                  adult human stage
# NivoExposed_tumor_Near                                                 adult human stage
# UT1_kidney                                                             adult human stage
# UT1_tumor_Center                                                       adult human stage
# UT1_tumor_Far                                                          adult human stage
# UT1_tumor_Near                                                         adult human stage
# UT2_kidney                                                             adult human stage
# UT2_tumor_Center                                                       adult human stage
# UT2_tumor_Far                                                          adult human stage
# UT2_tumor_Near                                                         adult human stage
#
#                                                    donor_organism.development_stage.ontology  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                         HsapDv:0000087
# IpiNivo_Complete_kidney                                                       HsapDv:0000087
# IpiNivo_Complete_tumor_Center                                                 HsapDv:0000087
# IpiNivo_Complete_tumor_Far                                                    HsapDv:0000087
# IpiNivo_Complete_tumor_Near                                                   HsapDv:0000087
# IpiNivo_Mixed_PBMC                                                            HsapDv:0000087
# IpiNivo_Mixed_kidney                                                          HsapDv:0000087
# IpiNivo_Mixed_tumor_Center                                                    HsapDv:0000087
# IpiNivo_Mixed_tumor_Far                                                       HsapDv:0000087
# IpiNivo_Mixed_tumor_Near                                                      HsapDv:0000087
# IpiNivo_Resistant_PBMC                                                        HsapDv:0000087
# IpiNivo_Resistant_kidney                                                      HsapDv:0000087
# IpiNivo_Resistant_lymph_node                                                  HsapDv:0000087
# IpiNivo_Resistant_tumor_Center                                                HsapDv:0000087
# IpiNivo_Resistant_tumor_Far                                                   HsapDv:0000087
# IpiNivo_Resistant_tumor_Near                                                  HsapDv:0000087
# NivoExposed_PBMC                                                              HsapDv:0000087
# NivoExposed_kidney                                                            HsapDv:0000087
# NivoExposed_tumor_Center                                                      HsapDv:0000087
# NivoExposed_tumor_Far                                                         HsapDv:0000087
# NivoExposed_tumor_Near                                                        HsapDv:0000087
# UT1_kidney                                                                    HsapDv:0000087
# UT1_tumor_Center                                                              HsapDv:0000087
# UT1_tumor_Far                                                                 HsapDv:0000087
# UT1_tumor_Near                                                                HsapDv:0000087
# UT2_kidney                                                                    HsapDv:0000087
# UT2_tumor_Center                                                              HsapDv:0000087
# UT2_tumor_Far                                                                 HsapDv:0000087
# UT2_tumor_Near                                                                HsapDv:0000087
#
#                                                    donor_organism.development_stage.ontology_label  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                            human adult stage
# IpiNivo_Complete_kidney                                                          human adult stage
# IpiNivo_Complete_tumor_Center                                                    human adult stage
# IpiNivo_Complete_tumor_Far                                                       human adult stage
# IpiNivo_Complete_tumor_Near                                                      human adult stage
# IpiNivo_Mixed_PBMC                                                               human adult stage
# IpiNivo_Mixed_kidney                                                             human adult stage
# IpiNivo_Mixed_tumor_Center                                                       human adult stage
# IpiNivo_Mixed_tumor_Far                                                          human adult stage
# IpiNivo_Mixed_tumor_Near                                                         human adult stage
# IpiNivo_Resistant_PBMC                                                           human adult stage
# IpiNivo_Resistant_kidney                                                         human adult stage
# IpiNivo_Resistant_lymph_node                                                     human adult stage
# IpiNivo_Resistant_tumor_Center                                                   human adult stage
# IpiNivo_Resistant_tumor_Far                                                      human adult stage
# IpiNivo_Resistant_tumor_Near                                                     human adult stage
# NivoExposed_PBMC                                                                 human adult stage
# NivoExposed_kidney                                                               human adult stage
# NivoExposed_tumor_Center                                                         human adult stage
# NivoExposed_tumor_Far                                                            human adult stage
# NivoExposed_tumor_Near                                                           human adult stage
# UT1_kidney                                                                       human adult stage
# UT1_tumor_Center                                                                 human adult stage
# UT1_tumor_Far                                                                    human adult stage
# UT1_tumor_Near                                                                   human adult stage
# UT2_kidney                                                                       human adult stage
# UT2_tumor_Center                                                                 human adult stage
# UT2_tumor_Far                                                                    human adult stage
# UT2_tumor_Near                                                                   human adult stage
#
#                                                                         donor_organism.diseases.text  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                Clear cell renal cell carcinoma
# IpiNivo_Complete_kidney                                              Clear cell renal cell carcinoma
# IpiNivo_Complete_tumor_Center                                        Clear cell renal cell carcinoma
# IpiNivo_Complete_tumor_Far                                           Clear cell renal cell carcinoma
# IpiNivo_Complete_tumor_Near                                          Clear cell renal cell carcinoma
# IpiNivo_Mixed_PBMC                                                   Clear cell renal cell carcinoma
# IpiNivo_Mixed_kidney                                                 Clear cell renal cell carcinoma
# IpiNivo_Mixed_tumor_Center                                           Clear cell renal cell carcinoma
# IpiNivo_Mixed_tumor_Far                                              Clear cell renal cell carcinoma
# IpiNivo_Mixed_tumor_Near                                             Clear cell renal cell carcinoma
# IpiNivo_Resistant_PBMC                              Clear cell renal cell carcinoma||Lymphadenopathy
# IpiNivo_Resistant_kidney                            Clear cell renal cell carcinoma||Lymphadenopathy
# IpiNivo_Resistant_lymph_node                        Clear cell renal cell carcinoma||Lymphadenopathy
# IpiNivo_Resistant_tumor_Center                      Clear cell renal cell carcinoma||Lymphadenopathy
# IpiNivo_Resistant_tumor_Far                         Clear cell renal cell carcinoma||Lymphadenopathy
# IpiNivo_Resistant_tumor_Near                        Clear cell renal cell carcinoma||Lymphadenopathy
# NivoExposed_PBMC                                                     Clear cell renal cell carcinoma
# NivoExposed_kidney                                                   Clear cell renal cell carcinoma
# NivoExposed_tumor_Center                                             Clear cell renal cell carcinoma
# NivoExposed_tumor_Far                                                Clear cell renal cell carcinoma
# NivoExposed_tumor_Near                                               Clear cell renal cell carcinoma
# UT1_kidney                                                           Clear cell renal cell carcinoma
# UT1_tumor_Center                                                     Clear cell renal cell carcinoma
# UT1_tumor_Far                                                        Clear cell renal cell carcinoma
# UT1_tumor_Near                                                       Clear cell renal cell carcinoma
# UT2_kidney                                                           Clear cell renal cell carcinoma
# UT2_tumor_Center                                                     Clear cell renal cell carcinoma
# UT2_tumor_Far                                                        Clear cell renal cell carcinoma
# UT2_tumor_Near                                                       Clear cell renal cell carcinoma
#
#                                                    donor_organism.diseases.ontology  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                 MONDO:0005005
# IpiNivo_Complete_kidney                                               MONDO:0005005
# IpiNivo_Complete_tumor_Center                                         MONDO:0005005
# IpiNivo_Complete_tumor_Far                                            MONDO:0005005
# IpiNivo_Complete_tumor_Near                                           MONDO:0005005
# IpiNivo_Mixed_PBMC                                                    MONDO:0005005
# IpiNivo_Mixed_kidney                                                  MONDO:0005005
# IpiNivo_Mixed_tumor_Center                                            MONDO:0005005
# IpiNivo_Mixed_tumor_Far                                               MONDO:0005005
# IpiNivo_Mixed_tumor_Near                                              MONDO:0005005
# IpiNivo_Resistant_PBMC                                    MONDO:0005005||HP:0002716
# IpiNivo_Resistant_kidney                                  MONDO:0005005||HP:0002716
# IpiNivo_Resistant_lymph_node                              MONDO:0005005||HP:0002716
# IpiNivo_Resistant_tumor_Center                            MONDO:0005005||HP:0002716
# IpiNivo_Resistant_tumor_Far                               MONDO:0005005||HP:0002716
# IpiNivo_Resistant_tumor_Near                              MONDO:0005005||HP:0002716
# NivoExposed_PBMC                                                      MONDO:0005005
# NivoExposed_kidney                                                    MONDO:0005005
# NivoExposed_tumor_Center                                              MONDO:0005005
# NivoExposed_tumor_Far                                                 MONDO:0005005
# NivoExposed_tumor_Near                                                MONDO:0005005
# UT1_kidney                                                            MONDO:0005005
# UT1_tumor_Center                                                      MONDO:0005005
# UT1_tumor_Far                                                         MONDO:0005005
# UT1_tumor_Near                                                        MONDO:0005005
# UT2_kidney                                                            MONDO:0005005
# UT2_tumor_Center                                                      MONDO:0005005
# UT2_tumor_Far                                                         MONDO:0005005
# UT2_tumor_Near                                                        MONDO:0005005
#
#                                                          donor_organism.diseases.ontology_label  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                clear cell renal carcinoma
# IpiNivo_Complete_kidney                                              clear cell renal carcinoma
# IpiNivo_Complete_tumor_Center                                        clear cell renal carcinoma
# IpiNivo_Complete_tumor_Far                                           clear cell renal carcinoma
# IpiNivo_Complete_tumor_Near                                          clear cell renal carcinoma
# IpiNivo_Mixed_PBMC                                                   clear cell renal carcinoma
# IpiNivo_Mixed_kidney                                                 clear cell renal carcinoma
# IpiNivo_Mixed_tumor_Center                                           clear cell renal carcinoma
# IpiNivo_Mixed_tumor_Far                                              clear cell renal carcinoma
# IpiNivo_Mixed_tumor_Near                                             clear cell renal carcinoma
# IpiNivo_Resistant_PBMC                              clear cell renal carcinoma||Lymphadenopathy
# IpiNivo_Resistant_kidney                            clear cell renal carcinoma||Lymphadenopathy
# IpiNivo_Resistant_lymph_node                        clear cell renal carcinoma||Lymphadenopathy
# IpiNivo_Resistant_tumor_Center                      clear cell renal carcinoma||Lymphadenopathy
# IpiNivo_Resistant_tumor_Far                         clear cell renal carcinoma||Lymphadenopathy
# IpiNivo_Resistant_tumor_Near                        clear cell renal carcinoma||Lymphadenopathy
# NivoExposed_PBMC                                                     clear cell renal carcinoma
# NivoExposed_kidney                                                   clear cell renal carcinoma
# NivoExposed_tumor_Center                                             clear cell renal carcinoma
# NivoExposed_tumor_Far                                                clear cell renal carcinoma
# NivoExposed_tumor_Near                                               clear cell renal carcinoma
# UT1_kidney                                                           clear cell renal carcinoma
# UT1_tumor_Center                                                     clear cell renal carcinoma
# UT1_tumor_Far                                                        clear cell renal carcinoma
# UT1_tumor_Near                                                       clear cell renal carcinoma
# UT2_kidney                                                           clear cell renal carcinoma
# UT2_tumor_Center                                                     clear cell renal carcinoma
# UT2_tumor_Far                                                        clear cell renal carcinoma
# UT2_tumor_Near                                                       clear cell renal carcinoma
#
#                                                              donor_organism.medical_history.treatment  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               Patient was placed on ipilimumab and nivolumab...
# IpiNivo_Complete_kidney                             Patient was placed on ipilimumab and nivolumab...
# IpiNivo_Complete_tumor_Center                       Patient was placed on ipilimumab and nivolumab...
# IpiNivo_Complete_tumor_Far                          Patient was placed on ipilimumab and nivolumab...
# IpiNivo_Complete_tumor_Near                         Patient was placed on ipilimumab and nivolumab...
# IpiNivo_Mixed_PBMC                                  Patient had a near complete response in the lu...
# IpiNivo_Mixed_kidney                                Patient had a near complete response in the lu...
# IpiNivo_Mixed_tumor_Center                          Patient had a near complete response in the lu...
# IpiNivo_Mixed_tumor_Far                             Patient had a near complete response in the lu...
# IpiNivo_Mixed_tumor_Near                            Patient had a near complete response in the lu...
# IpiNivo_Resistant_PBMC                              Patient received 4 doses of Nivolumab followed...
# IpiNivo_Resistant_kidney                            Patient received 4 doses of Nivolumab followed...
# IpiNivo_Resistant_lymph_node                        Patient received 4 doses of Nivolumab followed...
# IpiNivo_Resistant_tumor_Center                      Patient received 4 doses of Nivolumab followed...
# IpiNivo_Resistant_tumor_Far                         Patient received 4 doses of Nivolumab followed...
# IpiNivo_Resistant_tumor_Near                        Patient received 4 doses of Nivolumab followed...
# NivoExposed_PBMC                                    Patient was enrolled in a clinical trial of ne...
# NivoExposed_kidney                                  Patient was enrolled in a clinical trial of ne...
# NivoExposed_tumor_Center                            Patient was enrolled in a clinical trial of ne...
# NivoExposed_tumor_Far                               Patient was enrolled in a clinical trial of ne...
# NivoExposed_tumor_Near                              Patient was enrolled in a clinical trial of ne...
# UT1_kidney                                          Patient underwent radical nephrectomy and was ...
# UT1_tumor_Center                                    Patient underwent radical nephrectomy and was ...
# UT1_tumor_Far                                       Patient underwent radical nephrectomy and was ...
# UT1_tumor_Near                                      Patient underwent radical nephrectomy and was ...
# UT2_kidney                                          Patient underwent a cytoreductive nephrectomy ...
# UT2_tumor_Center                                    Patient underwent a cytoreductive nephrectomy ...
# UT2_tumor_Far                                       Patient underwent a cytoreductive nephrectomy ...
# UT2_tumor_Near                                      Patient underwent a cytoreductive nephrectomy ...
#
#                                                    donor_organism.medical_history.medication  \
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                                                    Ipilumab, Nivolumab
# IpiNivo_Complete_kidney                                                  Ipilumab, Nivolumab
# IpiNivo_Complete_tumor_Center                                            Ipilumab, Nivolumab
# IpiNivo_Complete_tumor_Far                                               Ipilumab, Nivolumab
# IpiNivo_Complete_tumor_Near                                              Ipilumab, Nivolumab
# IpiNivo_Mixed_PBMC                                                       Ipilumab, Nivolumab
# IpiNivo_Mixed_kidney                                                     Ipilumab, Nivolumab
# IpiNivo_Mixed_tumor_Center                                               Ipilumab, Nivolumab
# IpiNivo_Mixed_tumor_Far                                                  Ipilumab, Nivolumab
# IpiNivo_Mixed_tumor_Near                                                 Ipilumab, Nivolumab
# IpiNivo_Resistant_PBMC                                                   Ipilumab, Nivolumab
# IpiNivo_Resistant_kidney                                                 Ipilumab, Nivolumab
# IpiNivo_Resistant_lymph_node                                             Ipilumab, Nivolumab
# IpiNivo_Resistant_tumor_Center                                           Ipilumab, Nivolumab
# IpiNivo_Resistant_tumor_Far                                              Ipilumab, Nivolumab
# IpiNivo_Resistant_tumor_Near                                             Ipilumab, Nivolumab
# NivoExposed_PBMC                                                                   Nivolumab
# NivoExposed_kidney                                                                 Nivolumab
# NivoExposed_tumor_Center                                                           Nivolumab
# NivoExposed_tumor_Far                                                              Nivolumab
# NivoExposed_tumor_Near                                                             Nivolumab
# UT1_kidney                                                                               nan
# UT1_tumor_Center                                                                         nan
# UT1_tumor_Far                                                                            nan
# UT1_tumor_Near                                                                           nan
# UT2_kidney                                                                               nan
# UT2_tumor_Center                                                                         nan
# UT2_tumor_Far                                                                            nan
# UT2_tumor_Near                                                                           nan
#
#                                                            project_label
# specimen_from_organism.biomaterial_core.biomate...
# IpiNivo_Complete_PBMC                               ImmuneLandscapeccRCC
# IpiNivo_Complete_kidney                             ImmuneLandscapeccRCC
# IpiNivo_Complete_tumor_Center                       ImmuneLandscapeccRCC
# IpiNivo_Complete_tumor_Far                          ImmuneLandscapeccRCC
# IpiNivo_Complete_tumor_Near                         ImmuneLandscapeccRCC
# IpiNivo_Mixed_PBMC                                  ImmuneLandscapeccRCC
# IpiNivo_Mixed_kidney                                ImmuneLandscapeccRCC
# IpiNivo_Mixed_tumor_Center                          ImmuneLandscapeccRCC
# IpiNivo_Mixed_tumor_Far                             ImmuneLandscapeccRCC
# IpiNivo_Mixed_tumor_Near                            ImmuneLandscapeccRCC
# IpiNivo_Resistant_PBMC                              ImmuneLandscapeccRCC
# IpiNivo_Resistant_kidney                            ImmuneLandscapeccRCC
# IpiNivo_Resistant_lymph_node                        ImmuneLandscapeccRCC
# IpiNivo_Resistant_tumor_Center                      ImmuneLandscapeccRCC
# IpiNivo_Resistant_tumor_Far                         ImmuneLandscapeccRCC
# IpiNivo_Resistant_tumor_Near                        ImmuneLandscapeccRCC
# NivoExposed_PBMC                                    ImmuneLandscapeccRCC
# NivoExposed_kidney                                  ImmuneLandscapeccRCC
# NivoExposed_tumor_Center                            ImmuneLandscapeccRCC
# NivoExposed_tumor_Far                               ImmuneLandscapeccRCC
# NivoExposed_tumor_Near                              ImmuneLandscapeccRCC
# UT1_kidney                                          ImmuneLandscapeccRCC
# UT1_tumor_Center                                    ImmuneLandscapeccRCC
# UT1_tumor_Far                                       ImmuneLandscapeccRCC
# UT1_tumor_Near                                      ImmuneLandscapeccRCC
# UT2_kidney                                          ImmuneLandscapeccRCC
# UT2_tumor_Center                                    ImmuneLandscapeccRCC
# UT2_tumor_Far                                       ImmuneLandscapeccRCC
# UT2_tumor_Near                                      ImmuneLandscapeccRCC
#
# [29 rows x 131 columns]

# %%
from os.path import basename, splitext
report_entity_clean = report_entity.replace(" ","-")
flattened_filename = f'{output_dir}/{splitext(basename(spreadsheet))[0]}_denormalised_biomaterial.xlsx'
flattened.to_excel(flattened_filename)

# %%
import openpyxl
import getpass
fh = openpyxl.load_workbook(flattened_filename)

obj = fh.properties   

fh.properties.title = f'denormalised hca metadata for project {project_label} showing {report_entity}'
fh.properties.version = version
fh.properties.keywords = f'flattened,hca,metadata,{project_label},{report_entity_clean}'
fh.properties.creator = getpass.getuser( )
fh.properties.lastModifiedBy = getpass.getuser( )
fh.properties.created=datetime.now()
fh.properties.modified=datetime.now()


fh.save(flattened_filename)

# %% [markdown]
# # normalise a flattened spreadsheet and recover original

# %%
from openpyxl import Workbook

fqn_separator = '.'

df_by_sheet = {}

wb = Workbook()
for col in flattened.columns:
    if col.startswith('project'):
        sheet_name = 'project'
    else:
        try:
            sheet_name, fq_name = col.split(fqn_separator, maxsplit=1)
        except ValueError as e:
            print(f'problem converting col name: {col}: {e}')
        
    if sheet_name not in df_by_sheet:
        df_by_sheet[sheet_name]=pd.DataFrame()
    sheet_df = df_by_sheet[sheet_name]
    try:
        sheet_df.insert(loc=0,
                        column=col, 
                        value=flattened[col])
    except ValueError as e:
        print(f'problem importing column data: {col}: {e}')
        print(flattened[col].head())
        break

dest_filename = f'{output_dir}/reconstructed.xlsx'
with pd.ExcelWriter(dest_filename) as xl_writer:  
    for sheet_name, sheet_df in df_by_sheet.items():
        sheet_df.drop_duplicates(inplace=True)
        sheet_df.to_excel(xl_writer, sheet_name=sheet_name)
                          
for sheet_name, sheet_df in df_by_sheet.items():                          
    original_sheet_name = sheet_name[0].upper()+sheet_name[1:].replace('_', ' ')
    original_sheet = pd.read_excel(spreadsheet, original_sheet_name)
    print(f'{sheet_name}: rows {len(sheet_df)}, original: {original_sheet_name}, {len(original_sheet)}')
